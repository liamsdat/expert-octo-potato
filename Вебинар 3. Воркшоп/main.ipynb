# %% [markdown]
# ## 1. Jupyter Notebook, Google Colab

# %% [markdown]
# ### Имеется поддержка HTML, советуют использовать быстрые команды, автозаполнение и тп

# %% [markdown]
# ## 2. Арифметические операции

# %%
print(1+1)
# Out:
# 2

# %%
print(2 - 1, 5 + 6)
# Out:
# 1 11

# %%
print(2-1)
# Для вывода в jupyter необязательно использовать print(число символ число)
# Out:
# 1

# %%
1 + 1
# Out:
# 2

# %%
5 * 6
# Out:
# 30

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 4
# Out:
# 2

# %%
10 == 4*2 + 2 # когда используем // в ответ идёт только целочисленная часть, то есть деление идёт по модулю
# Out:
# True

# %%
2 ** 100 # Равносильно 2^100
# Out:
# 1267650600228229401496703205376

# %%
2*2*2*2*2 == 2**5
# Out:
# True

# %%
40 % 15 # Выводит остаток от деления
# Out:
# 10

# %% [markdown]
# # 3. Переменные

# %%
b = 10 + 20
a =  b * 30
c = a / b
print('Answer: ', c)
# Out:
# Answer:  30.0

# %% [markdown]
# # 4. Строки

# %%
my_string = 'He said: "Hello"'
print(my_string)

# %%
my_string_2 = "Hello \"World\"!"
print(my_string_2)
# Out:
# Hello "World"!

# %% [markdown]
# # 5. Операторы сравнения

# %%
2++1
# Out:
# 3

# %%
2 > 1
# Out:
# True

# %%
10 < 9
# Out:
# False

# %%
10 > 10
# Out:
# False

# %%
7 == 7
# Out:
# True

# %%
a = 1

# %%
a == 1
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
5 > 4 < 0
# Out:
# False

# %%
print('b' > 'B')
# Out:
# True

# %%
print('c' > 'a')
# Out:
# True

# %%
print('abc' > 'aba')
# Out:
# True

# %%
len('abc') < len('fgdfgdfgdf')
# Out:
# True

# %% [markdown]
# # 6. Условные конструкции

# %%
'2020-05-01' < '2020-05-09'
# Out:
# True

# %%
'logs_2019-12-31.csv' < 'logs_2020-01-01.csv'
# Out:
# True

# %% [markdown]
# # 7. Логические операторы and и or

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True or True
# Out:
# True

# %%
not True or not False
# Out:
# True

# %%
not True and not False
# Out:
# False

# %%
not False
# Out:
# True

# %%
((9>7) and (2<4))
# Out:
# True

# %%
(8==8) or (6!=6)
# Out:
# True

# %%
not(3 <= 1)
# Out:
# True
