# %%
list1 = [i*1 for i in range(0, 6)]
list2 = [i + 1 for i in range(3, 9)]
print(list1)
print(list2)
jl = []
for j in list1:
    for k in list2:
        if j == k:
            jl.append(j)

print(jl)
# Out:
# [0, 1, 2, 3, 4, 5]
# [4, 5, 6, 7, 8, 9]
# [4, 5]
