# %%
my_string = "Hello World"

# %%
my_string.upper()
# Out:
# 'HELLO WORLD'

# %%
my_string.lower()
# Out:
# 'hello world'

# %%
my_string.capitalize()
# Out:
# 'Hello world'

# %%
new_string = my_string.replace('Hello', 'Goodbye')
my_string
# Out:
# 'Hello World'

# %%
len(my_string)
# Out:
# 11

# %%
# Индексация и срезы

# %%
my_string = "Hello World"

# %%
my_string[2]
# Out:
# 'l'

# %%
my_string[-1]
# Out:
# 'd'

# %%
my_string[0:5] # 0 - начальный индекс, 5 - конечный индекс
# Out:
# 'Hello'

# %%
my_string[0:5:2] # 0 - начальный индекс, 5 - конечный индекс, 2 - шаг
# Out:
# 'Hlo'

# %%
list0 = ['a', 'b', 'c', 'd', 'e', 'f']
list1 = list[0:len(list0)] # or list.copy()

list1[0] = 'x'
print(list1)
# Out:
# ['x', 'b', 'c', 'd', 'e', 'f']

# %%
my_string[6:]
# Out:
# 'World'

# %%
my_string[:5]
# Out:
# 'Hello'

# %%
my_string[5:6]
# Out:
# ' '

# %%
'o' in my_string
# Out:
# True

# %%
# f-string
lang = 'Python'
name = "Sol0mon"
t = f"Hello my name is {name}, i junior on {lang} "
print(t)
# Out:
# Hello my name is Sol0mon, i junior on Python

# %%
month_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

income_list = [13_000, 14_000, 15_000, 13_500, 17_600, 14_300, 15_000, 14_300, 15_000, 12_350, 16_500, 11_400]

income_by_month = [
    ['Jan', 13_000],
    ['Feb', 14_000],
    ['Mar', 15_000],
    ['Apr', 13_500],
    ['May', 17_600],
    ['Jun', 14_300],
    ['Jul', 15_000],
    ['Aug', 14_300],
    ['Sep', 15_000],
    ['Oct', 12_350],
    ['Nov', 16_500],
    ['Dec', 11_400],

]

# %%
print(type(month_list))
print(type(income_list))
print(type(income_by_month))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
# индексация элементов в списке
print(month_list[0])
print(month_list[-1])
print(income_by_month[8][1])
# Out:
# Jan
# Dec
# 15000

# %%
# срезы
print(income_by_month[1:3])
print(income_by_month[0:-3])
print(income_by_month[0:9])
print(income_by_month[2:5])
# Out:
# [['Feb', 14000], ['Mar', 15000]]
# [['Jan', 13000], ['Feb', 14000], ['Mar', 15000], ['Apr', 13500], ['May', 17600], ['Jun', 14300], ['Jul', 15000], ['Aug', 14300], ['Sep', 15000]]
# [['Jan', 13000], ['Feb', 14000], ['Mar', 15000], ['Apr', 13500], ['May', 17600], ['Jun', 14300], ['Jul', 15000], ['Aug', 14300], ['Sep', 15000]]
# [['Mar', 15000], ['Apr', 13500], ['May', 17600]]

# %%
# Изменение списков
income_by_month[0][1] = 12_900
print(income_by_month)
# Out:
# [['Jan', 12900], ['Feb', 14000], ['Mar', 15000], ['Apr', 13500], ['May', 17600], ['Jun', 14300], ['Jul', 15000], ['Aug', 14300], ['Sep', 15000], ['Oct', 12350], ['Nov', 16500], ['Dec', 11400]]

# %%
income_by_month[0:3] = [['Jan', 12_900], ['Feb', 12_345], ['Mar', 11_700]]
print(income_by_month)
# Out:
# [['Jan', 12900], ['Feb', 12345], ['Mar', 11700], ['Apr', 13500], ['May', 17600], ['Jun', 14300], ['Jul', 15000], ['Aug', 14300], ['Sep', 15000], ['Oct', 12350], ['Nov', 16500], ['Dec', 11400]]

# %%
a, b = income_by_month[0:2]

# %%
print(a, b)
# Out:
# ['Jan', 12900] ['Feb', 12345]

# %%
a, b = 1, 2; a + b
# Out:
# 3

# %%
x, y = 'he'; print(x, y)
# Out:
# h e

# %%
income_by_month_2 = [['Jan', 12_900],['Feb', 12_345],['Mar', 11_700]]
income_by_month = income_by_month + income_by_month_2
print(income_by_month)
len(income_by_month)
# Out:
# [['Jan', 12900], ['Feb', 12345], ['Mar', 11700], ['Apr', 13500], ['May', 17600], ['Jun', 14300], ['Jul', 15000], ['Aug', 14300], ['Sep', 15000], ['Oct', 12350], ['Nov', 16500], ['Dec', 11400], ['Jan', 12900], ['Feb', 12345], ['Mar', 11700]]
# 15

# %%
data = ['first', 'second', 'third', 'fourth', 'fifth', 'six']
first = data[0]
print(first)
# Out:
# first

# %%
first, second, third = ['first', 'second', 'third']
print(first, second, third)
# Out:
# first second third

# %%
data = ['first', 'second', 'third', 'fourth', 'fifth', 'six']
first, *_ = data
print(first, *_)
# Out:
# first second third fourth fifth six

# %%
first, *other, last = data
print(*other, last)
# Out:
# second third fourth fifth six

# %%
income_by_month
# Out:
# [['Jan', 12900],
#  ['Feb', 12345],
#  ['Mar', 11700],
#  ['Apr', 13500],
#  ['May', 17600],
#  ['Jun', 14300],
#  ['Jul', 15000],
#  ['Aug', 14300],
#  ['Sep', 15000],
#  ['Oct', 12350],
#  ['Nov', 16500],
#  ['Dec', 11400],
#  ['Jan', 12900],
#  ['Feb', 12345],
#  ['Mar', 11700]]

# %%
del(income_by_month[-1])
income_by_month
# Out:
# [['Jan', 12900],
#  ['Feb', 12345],
#  ['Mar', 11700],
#  ['Apr', 13500],
#  ['May', 17600],
#  ['Jun', 14300],
#  ['Jul', 15000],
#  ['Aug', 14300],
#  ['Sep', 15000],
#  ['Oct', 12350],
#  ['Nov', 16500],
#  ['Dec', 11400],
#  ['Jan', 12900],
#  ['Feb', 12345]]

# %%
month_list.remove('Jun')
print(month_list)
# Out:
# ['Jan', 'Mar', 'Apr', 'May', 'Jul', 'Aug', 'Oct', 'Nov', 'Dec']

# %%
income_by_month.append(['Dec', 17_000])
income_by_month
# Out:
# [['Jan', 12900],
#  ['Feb', 12345],
#  ['Mar', 11700],
#  ['Apr', 13500],
#  ['May', 17600],
#  ['Jun', 14300],
#  ['Jul', 15000],
#  ['Aug', 14300],
#  ['Sep', 15000],
#  ['Oct', 12350],
#  ['Nov', 16500],
#  ['Dec', 11400],
#  ['Jan', 12900],
#  ['Feb', 12345],
#  ['Dec', 17000]]

# %%
income_by_month.insert(2, ['Chill', 12_900])
income_by_month
# Out:
# [['Jan', 12900],
#  ['Feb', 12345],
#  ['Chill', 12900],
#  ['Mar', 11700],
#  ['Apr', 13500],
#  ['May', 17600],
#  ['Jun', 14300],
#  ['Jul', 15000],
#  ['Aug', 14300],
#  ['Sep', 15000],
#  ['Oct', 12350],
#  ['Nov', 16500],
#  ['Dec', 11400],
#  ['Jan', 12900],
#  ['Feb', 12345],
#  ['Dec', 17000]]

# %%
income_list.count(13000)
# Out:
# 1

# %%
len(income_by_month)
# Out:
# 16

# %%
month_list.reverse()
month_list
# Out:
# ['Dec', 'Nov', 'Oct', 'Aug', 'Jul', 'May', 'Apr', 'Mar', 'Jan']

# %%
sum(income_list)
# Out:
# 171950

# %%
max(income_list)
# Out:
# 17600

# %%
min(income_list)
# Out:
# 11400

# %%
sorted(income_list)
# Out:
# [11400,
#  12350,
#  13000,
#  13500,
#  14000,
#  14300,
#  14300,
#  15000,
#  15000,
#  15000,
#  16500,
#  17600]

# %%
sorted(income_list, reverse=True)
# Out:
# [17600,
#  16500,
#  15000,
#  15000,
#  15000,
#  14300,
#  14300,
#  14000,
#  13500,
#  13000,
#  12350,
#  11400]

# %%
sorted(month_list, reverse=True)
# Out:
# ['Oct', 'Nov', 'May', 'Mar', 'Jul', 'Jan', 'Dec', 'Aug', 'Apr']

# %%
a = [1, 2, 3]
b = a

# %%
id(a), id(b)
# Out:
# (4396840384, 4396840384)

# %%
a = [1, 2, 3]
b = a[:]
id(a), id(b)
# Out:
# (4396804224, 4396803904)

# %%
queries_string = "русское казино, деньги взаймы, программирование, Альфа-банк, новые сериалы смотреть бесплатно, кино афиша"
queries_list = queries_string.split(',')
print(queries_list)
# Out:
# ['русское казино', ' деньги взаймы', ' программирование', ' Альфа-банк', ' новые сериалы смотреть бесплатно', ' кино афиша']

# %%
len(queries_list[0].split(' '))
# Out:
# 2

# %%
parts = ['Hello', "World", 'I', 'am', 'cool']
s = ""
for part in parts:
    s = s + part + " "
print(s)
# Out:
# Hello World I am cool

# %%
s = " ".join(parts)
s
# Out:
# 'Hello World I am cool'

# %%
even = [x * 2 for x in range(10) if x % 2 == 0]
even
# Out:
# [0, 4, 8, 12, 16]

# %%
even = (x * 2 for x in range(10) if x % 2 == 0)
print(even)
# Out:
# <generator object <genexpr> at 0x106198930>
